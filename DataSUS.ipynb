# %%
pip install pysus
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached pysus-0.9.4-py3-none-any.whl (1.3 MB)
# ...
#   Using cached dbfread-2.0.7-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached wget-3.2-py3-none-any.whl
# ...
#   Using cached fastparquet-0.8.3-cp310-cp310-win_amd64.whl (603 kB)
# ...
#   Using cached Unidecode-1.3.7-py3-none-any.whl (235 kB)
# ...
#   Using cached pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
# ...
#   Using cached loguru-0.6.0-py3-none-any.whl (58 kB)
# ...
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# ...
#   Using cached elasticsearch-7.16.2-py2.py3-none-any.whl (385 kB)
# ...
#      -------------------------------------- 114.3/114.3 kB 1.3 MB/s eta 0:00:00
# ...
#   Using cached pyarrow-13.0.0-cp310-cp310-win_amd64.whl (24.3 MB)
# ...
#   Using cached pyreaddbc-1.0.0.tar.gz (43 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
# ...

# %%
import pysus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\brunobezerra\PYTHON PROJETOS\PROJETOS\DataSUS\DataSUS.ipynb Célula 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/brunobezerra/PYTHON%20PROJETOS/PROJETOS/DataSUS/DataSUS.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import pysus
#
# ModuleNotFoundError: No module named 'pysus'

# %%
from pysus.online_data.sinasc import download, get_available_years
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\brunobezerra\PYTHON PROJETOS\PROJETOS\DataSUS\DataSUS.ipynb Célula 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/brunobezerra/PYTHON%20PROJETOS/PROJETOS/DataSUS/DataSUS.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from pysus.online_data.sinasc import download, get_available_years
#       <a href='vscode-notebook-cell:/c%3A/Users/brunobezerra/PYTHON%20PROJETOS/PROJETOS/DataSUS/DataSUS.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'pysus'
