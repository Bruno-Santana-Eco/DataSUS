# %%
pip install pysus
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 23.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.8/441.8 kB 38.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 52.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.3/114.3 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 97.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 50.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 MB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.6/500.6 kB 40.3 MB/s eta 0:00:00
# ...

# %%
pip install geopandas

# %%
import pysus

# %%
from pysus.online_data.sinasc import download, get_available_years
import pandas as pd

# %%
from pysus.online_data.SIM import download

# %%
df = download(state='BA',year=2015)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-13cbfdd2ca6f> in <cell line: 1>()
# ----> 1 df = download(state='BA',year=2015)
#       2
#
# TypeError: download() got an unexpected keyword argument 'state'

# %%
from pysus.online_data import SIM, parquets_to_dataframe
from pysus.preprocessing.decoders import decodifica_idade_SIM, translate_variables_SIM

# %%
df = parquets_to_dataframe(SIM.download('BA',2019))
df
# Out:
#       ORIGEM TIPOBITO   DTOBITO HORAOBITO NATURAL CODMUNNATU    DTNASC IDADE  \
# 0          1        2  25092019     2030      829    291270   07091986   433
# 1          1        2  05102019     0250      829    291350   04061965   454
# 2          1        2  01102019     2030      833    330455   15081984   435
# 3          1        2  02102019     2038      829    291480   11061987   432
# 4          1        2  04102019     0500      829    290800   09021984   435
# ...      ...      ...       ...       ...     ...        ...       ...   ...
# 93360      1        2  12052019     1430      829    293180   20111959   459
# 93361      1        2  13052019     0847      829    291800   07111967   451
# 93362      1        2  14052019     1027      829    293330   25041954   465
# 93363      1        2  15052019     0920      829    291580   11101934   484
# 93364      1        2  16052019     1025      829    293330   17011980   439
#
# ...

# %%
df.head(5)
# Out:
#   ORIGEM TIPOBITO   DTOBITO HORAOBITO NATURAL CODMUNNATU    DTNASC IDADE  \
# 0      1        2  25092019     2030      829    291270   07091986   433
# 1      1        2  05102019     0250      829    291350   04061965   454
# 2      1        2  01102019     2030      833    330455   15081984   435
# 3      1        2  02102019     2038      829    291480   11061987   432
# 4      1        2  04102019     0500      829    290800   09021984   435
#
#    SEXO RACACOR  ... FONTES TPRESGINFO TPNIVELINV NUDIASINF DTCADINF  \
# 0     1       4  ...
# 1     1       4  ...
# 2     1       4  ...
# 3     1       4  ...
# 4     1       4  ...
#
#    MORTEPARTO DTCONCASO FONTESINF ALTCAUSA  CONTADOR
# 0                                           1339219
# 1                                           1339220
# 2                                           1339221
# 3                                           1339222
# 4                                           1339223
#
# [5 rows x 87 columns]
